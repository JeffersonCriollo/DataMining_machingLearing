# %% [markdown]
# ## Introdution to Python for maching learning

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the currents directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/echocardiogram/uci-echocardiogram/Index.txt
# /kaggle/input/echocardiogram/uci-echocardiogram/echocardiogram.names.txt
# /kaggle/input/echocardiogram/uci-echocardiogram/echocardiogram.data.csv
# /kaggle/input/servicearea/ServiceArea.csv
# /kaggle/input/networkcsv/Network.csv

# %%
#Create an array of 10 random integers between 1 and 100

a = (np.random.randint(1, 100, 10, int))
print(a)
print(type(a))
print(len(a))

#and then calculate the mean and standard deviation of the array.

print(a.mean())
print(np.std(a))
# Out:
# [91 77 61 43 58 73 21 81 25 20]
# <class 'numpy.ndarray'>
# 10
# 55.0
# 25.0

# %%
#Create a 2-dimensional array of 3 rows and 4 columns with random integer values.

b = (np.random.randint(1, 10, size=(3,4)))
print(b)

#Then, calculate the sum of each row and column.

b_sum_row = np.sum(b, axis=1)
print(b_sum_row)

b_sum_col = np.sum(b, axis=0)
print(b_sum_col)
# Out:
# [[1 1 7 1]
#  [3 5 4 9]
#  [1 1 3 6]]
# [10 21 11]
# [ 5  7 14 16]

# %%
#Create a DataFrame with 3 columns: "Name", "Age", and "City".Add at least 5 rows of data to theDataFrame.

data={
    "Name":["Victor", "Ed", "Luis", "Juan", "Alex"],
    "Age":[12, 15, 26, 45, 66],
    "City":["Quito", "Cali", "Manta", "Loja", "Cuenca"]
}

df = pd.DataFrame(data)
print(df)

#Then, filter the DataFrame to only include rows where the person's age is greater than
#or equal to 30

df_filter = df[df['Age'] >= 30]
print(df_filter)
# Out:
#      Name  Age    City
# 0  Victor   12   Quito
# 1      Ed   15    Cali
# 2    Luis   26   Manta
# 3    Juan   45    Loja
# 4    Alex   66  Cuenca
#    Name  Age    City
# 3  Juan   45    Loja
# 4  Alex   66  Cuenca

# %%
#Load a CSV file into a DataFrame and then calculate the mean, median, and mode 
#of one of the columns in the DataFrame.

from scipy import stats

df2 = pd.read_csv("../input/networkcsv/Network.csv")
print(df2)
print(np.mean(df2["IssuerId"]))
print(np.std(df2["IssuerId"]))
print(stats.mode(df2["IssuerId"]))
# Out:
#       BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0             2014        AK     21989       HIOS           6
# 1             2014        AK     38344       HIOS           6
# 2             2014        AK     38536       HIOS           2
# 3             2014        AK     42507       HIOS           3
# 4             2014        AK     73836       HIOS           6
# ...            ...       ...       ...        ...         ...
# 3817          2016        WV     75441      SERFF           2
# 3818          2016        WV     76526      SERFF           4
# 3819          2016        WV     76526      SERFF           4
# 3820          2016        WV     94562      SERFF           2
# 3821          2016        WV     96480      SERFF           2
#
#                ImportDate  IssuerId2 StateCode2             NetworkName  \
# 0     2014-03-19 07:06:49      21989         AK             ODS Premier
# 1     2013-08-28 08:15:53      38344         AK            HeritagePlus
# ...

# %%
#Create a scatter plot of random x and y values between 1 and 100

x_val= np.random.randint(1,100,50)
y_val= np.random.randint(1,100,50)

plt.scatter(x_val, y_val)

plt.title("Diagrama de Dispersión")
plt.xlabel("X")
plt.ylabel("Y")
# Out:
# Text(0, 0.5, 'Y')

# %%
#Load a CSV file into a DataFrame and then create a line chart of one 
#of the columns in the DataFrame

df3 = pd.read_csv("../input/servicearea/ServiceArea.csv")
df3
plt.plot(df3["IssuerId2"])

plt.title('Gráfico')
plt.xlabel('Índice')
plt.ylabel("IssuerId2")
# Out:
# Text(0, 0.5, 'IssuerId2')

# %% [markdown]
# # The Echocardiogram data set in the UCI Machine Learning repository contains information on a set of patients that suffered heart attacks at some point in the past.

# %% [markdown]
# Download the Echocardiogram data set and import it to a data frame. Read the information on the data set and find out how missing values are represented and make sure that they are properly represented.

# %%
df4 = pd.read_csv("/kaggle/input/echocardiogram/uci-echocardiogram/echocardiogram.data.csv")
df4
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df4 = pd.read_csv("/kaggle/input/echocardiogram/uci-echocardiogram/echocardiogram.data.csv")
#       2 df4
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# ...

# %% [markdown]
# ## Load the airquality data set regarding a set of New York Air Quality Measurements.

# %%
df5 = pd.read_csv("/kaggle/input/new-york-city-air-quality/air-quality.csv")
df5
# Out:
#       indicator_data_id  indicator_id  \
# 0                130728           646
# 1                130729           646
# 2                130730           646
# 3                130731           646
# 4                130732           646
# ...                 ...           ...
# 2764             151756           645
# 2765             151757           645
# 2766             151758           645
# 2767             151759           645
# 2768             151760           645
#
#                                                    name  \
# 0     Air Toxics Concentrations- Average Benzene Con...
# 1     Air Toxics Concentrations- Average Benzene Con...
# 2     Air Toxics Concentrations- Average Benzene Con...
# 3     Air Toxics Concentrations- Average Benzene Con...
# 4     Air Toxics Concentrations- Average Benzene Con...
# ...                                                 ...
# 2764  Traffic Density- Annual Vehicle Miles Traveled...
# ...

# %%
#For which attributes are there missing values?

df5.isnull().sum()
# Out:
# indicator_data_id     0
# indicator_id          0
# name                  0
# Measure               0
# geo_type_name         0
# geo_entity_id         0
# geo_entity_name       0
# year_description      0
# data_valuemessage    33
# dtype: int64

# %%
#¿Todos los atributos están en el tipo de datos más adecuado? 
#Realice los cambios que considere necesarios.

df5.dtypes

df5 = df5[~df5["year_description"].astype(str).str.contains(".")]

df5["year_description"] = pd.to_numeric(df5["year_description"])
# Out:
# indicator_data_id      int64
# indicator_id           int64
# name                  object
# Measure               object
# geo_type_name         object
# geo_entity_id          int64
# geo_entity_name       object
# year_description       int64
# data_valuemessage    float64
# dtype: object

# %%
df5.dtypes
# Out:
# indicator_data_id      int64
# indicator_id           int64
# name                  object
# Measure               object
# geo_type_name         object
# geo_entity_id          int64
# geo_entity_name       object
# year_description       int64
# data_valuemessage    float64
# dtype: object

# %%
#What period of the year do these records refer to?

df5["year_description"]
df5["year_description"]
# Out:
# Series([], Name: year_description, dtype: int64)
